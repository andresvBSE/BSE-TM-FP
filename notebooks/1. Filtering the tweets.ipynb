# %% [markdown]
# ## Preliminar steps

# %%
import pandas as pd
import numpy as np

import os
import re

import datetime
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

pd.set_option('max_colwidth', 280) # For printing the full text of the twee

# %%
# List of the file anmes to load (the ones that finish in s10.csv) from the data folder
files = [f for f in os.listdir('data/') if re.match(r'.*\_s10.csv', f)]
files
# Out:
# ['tweets_2110_s10.csv',
#  'tweets_2109_s10.csv',
#  'tweets_2108_s10.csv',
#  'tweets_2107_s10.csv']

# %%
data = [pd.read_csv('data/' + df) for df in files] # load the dataframes in a list
data = pd.concat(data, axis = 0) # concatenates the files to get and unique file
print(data.shape)
# Out:
# (650833, 20)

# %% [markdown]
# ## Exploring some probable filters to apply on the dataset
#
# ### Searching for spam tweets
#
# Twitter is widely used for bots and other types of users to use spam
#
#
# Given that nowadays creating a new project of cryptocurrencies has became easy, many new projects are created every day and twitter is used as a way to spread information about the new project. Spammers try to use popular hashtags or cashtags such as Bitcoin to reach some public interested in investing in new projects that is promoted as the next bitcoin, for its capacity to increase its price in the future.
#
# Common words on this regard are: amazing/excellent/amazing project. Here some examples of tweets wi

# %%
# Some examples of spam tweets
data['text_l'] = data['text'].str.lower()
data[data['text_l'].str.match(r'^(?=.*\b(?:best|strong|awesome|amazing|great|big|excellent|good|nice)\b).*project')].sample(5)
# Out:
#        Unnamed: 0                   id      conversation_id  \
# 75201      582767  1428301324362428418  1428288993184174081
# 99566      372733  1418833057407062016  1418831910189486081
# 24158      637545  1439050594526711809  1438836691503132673
# 50998      180081  1442236528168562693  1441734385397428228
# 89295       65498  1431984901008629762  1431974512006873089
#
#                  author_id                created_at  \
# 75201  1412799954058244102  2021-08-19T10:22:26.000Z
# 99566  1413861853189394435  2021-07-24T07:18:56.000Z
# 24158   772629764011995138  2021-09-18T02:16:12.000Z
# 50998  1394471630378651649  2021-09-26T21:15:58.000Z
# 89295  1410811107011223555  2021-08-29T14:19:40.000Z
#
#                                                                                                                                                                                                                                                                                      text  \
# 75201                                                                                                                      @AirdropStario good project \n@kmmanik33 \n@HaridashPaul \n@KSolymon \n\n#cryptocurrency #Crypto #Bitcoin #Ethereum #ETH #Airdrop #bounty #BSC #BNB #ALPHADOGE
# 99566                              Great Project. Keep it up team.\n\n@joyBasa27074877\n\n@Amit32116\n\n@sweetsh93416220\n\n#KITE  #Airdrop #Binance #Bitcoin #BakerySwap #BNB #PanCakeSwap #cryptocurrency #NFT #DeFi #BTC #BinanceSmartChain #BSC https://t.co/ye9giIe9Za…\nQuote Tweet
# 24158                                      @keplerswap @airdropinspect Good project and solid team❤️❤️❤️ i think in the near future i will see an unprecedentet growth of this project 🚀🚀🚀\n\n@anambrother \n@kusumayanto1 \n@MemedHariadi \n\n#BTC #ETH #KeplerSwap #SDS #Airdrops #DeFi
# 50998  @OfficialThemis with the opportunity to take part in this airdrop, I am very enthusiastic because this is an excellent project, let's take it to the moon.\n\n@rrahiqo \n@najwazakiyyah20 \n@iqbalwarwerwor \n\n#Airdrops #ThemisProtocol #Bitcoin #AirdropDet #crypto #Blockchain
# 89295              @CoinRizen Excellent and great projects...\nI have participated in following the guidelines and rules of this airdrop.I am sure that it will develop and be successful in the future.\n\n@Rajvai22\n@ray84_x\n@mo\n\n#Airdrops #Bitcoin #crypto #Blockchain #RizenCoin
#
#       lang               source  public_metrics.like_count  \
# 75201   en  Twitter for Android                          0
# 99566   en      Twitter Web App                          0
# 24158   en  Twitter for Android                          0
# 50998   en  Twitter for Android                          0
# 89295   en  Twitter for Android                          0
#
#        public_metrics.quote_count  ...  public_metrics.retweet_count  \
# 75201                           0  ...                             0
# 99566                           0  ...                             0
# 24158                           0  ...                             0
# 50998                           0  ...                             0
# 89295                           0  ...                             0
#
#        entities.annotations entities.cashtags  author.username  \
# 75201                   NaN               NaN        KingSoly9
# 99566                   NaN               NaN    Mamun90508981
# 24158                   NaN               NaN  tonisunduk_tony
# 50998                   NaN               NaN     PurnaasihEri
# 89295                   NaN               NaN           NewRX8
#
#       author.public_metrics.followers_count  \
# 75201                                   143
# 99566                                    16
# 24158                                    92
# 50998                                   170
# 89295                                   137
#
#        author.public_metrics.following_count  \
# 75201                                   3380
# 99566                                    446
# 24158                                   1741
# 50998                                   2106
# 89295                                   1041
#
#        author.public_metrics.listed_count  geo.country geo.country_code  \
# 75201                                  15          NaN              NaN
# 99566                                   1          NaN              NaN
# 24158                                   5          NaN              NaN
# 50998                                   9          NaN              NaN
# 89295                                   4          NaN              NaN
#
#                                                                                                                                                                                                                                                                                    text_l
# 75201                                                                                                                      @airdropstario good project \n@kmmanik33 \n@haridashpaul \n@ksolymon \n\n#cryptocurrency #crypto #bitcoin #ethereum #eth #airdrop #bounty #bsc #bnb #alphadoge
# 99566                              great project. keep it up team.\n\n@joybasa27074877\n\n@amit32116\n\n@sweetsh93416220\n\n#kite  #airdrop #binance #bitcoin #bakeryswap #bnb #pancakeswap #cryptocurrency #nft #defi #btc #binancesmartchain #bsc https://t.co/ye9giie9za…\nquote tweet
# 24158                                      @keplerswap @airdropinspect good project and solid team❤️❤️❤️ i think in the near future i will see an unprecedentet growth of this project 🚀🚀🚀\n\n@anambrother \n@kusumayanto1 \n@memedhariadi \n\n#btc #eth #keplerswap #sds #airdrops #defi
# 50998  @officialthemis with the opportunity to take part in this airdrop, i am very enthusiastic because this is an excellent project, let's take it to the moon.\n\n@rrahiqo \n@najwazakiyyah20 \n@iqbalwarwerwor \n\n#airdrops #themisprotocol #bitcoin #airdropdet #crypto #blockchain
# 89295              @coinrizen excellent and great projects...\ni have participated in following the guidelines and rules of this airdrop.i am sure that it will develop and be successful in the future.\n\n@rajvai22\n@ray84_x\n@mo\n\n#airdrops #bitcoin #crypto #blockchain #rizencoin
#
# [5 rows x 21 columns]

# %% [markdown]
# Similarly Airdrop is another token that is linked with the development of a new crypto project

# %% [markdown]
# Given that usually tweets associated with the promotion of a new project (airdrop) are highly possitive, this can bias our measure of sentiments over Bitcoin. For this reason we delete the tweet that contain a positive adjective before the work project. The same way we delete tweets with

# %%
# adjective project
data['delete_project'] = np.where(data['text_l'].str.contains(r'^(?=.*\b(?:best|strong|awesome|amazing|great|big|excellent|good|nice)\b).*project'), 1, 0)

# Airdrop word
data['delete_airdrop'] = np.where(data['text_l'].str.contains(r'airdrop'), 1, 0)

print('Proportion of positive project tweets: ', data['delete_project'].mean())
print('Proportion of tweets with the word aidrop:  ',data['delete_airdrop'].mean())
# Out:
# Proportion of positive project tweets:  0.14631710438776152
# Proportion of tweets with the word aidrop:   0.1963237881299811

# %% [markdown]
# Another easy way to identify tweets is by searchin with the word referral since those tweets are also about some people trying  capture other to be part of a investment and potencial scam. See the follow examples.

# %%
data[data['text'].str.contains('referral')].sample(5)
# Out:
#         Unnamed: 0                   id      conversation_id  \
# 124960     1319789  1411748935249563656  1411748935249563656
# 181834     1445584  1446557616113586176  1446557616113586176
# 121151      423129  1429567107629473792  1429567107629473792
# 90140      1269509  1412155864350347272  1412155864350347272
# 27451       358577  1430048931996598274  1430048931996598274
#
#                  author_id                created_at  \
# 124960           617853906  2021-07-04T18:09:09.000Z
# 181834           347865202  2021-10-08T19:26:26.000Z
# 121151           617853906  2021-08-22T22:12:13.000Z
# 90140            617853906  2021-07-05T21:06:09.000Z
# 27451   990831118072078341  2021-08-24T06:06:49.000Z
#
#                                                                                                                                                                                                                                                                                            text  \
# 124960                                                                               #freelance #freelancer #businessgrowth #grow #build #affiliatemarketing Check my website for #affiliate #referral #cashback #crypto #shopping #travel #business #dogecoin #bitcoin https://t.co/vBHLD11zwQ
# 181834                                                                                @airdropinspect \n\n@airdropinspect\n#Bitcoin\nChannel: https://t.co/LYIc063wan\n\nBuild bots with the referral system\nPromote Airdrop/Bounty/Giveaway/Referral Link\n\nContact: https://t.co/a49FMbzsFa
# 121151                         #Onlinemarketing #NetworkingPays #Online #Marketing #Networking #incomeforlife #payout #affiliatemarketing Check my #website #makemoney #earnmoney #affiliate #referral #cashback #crypto #shopping #travel #business #bitcoin #dogecoin https://t.co/vBHLD11zwQ
# 90140                                #Smart #seamless #freelancer #tools to #build, #manage, and #grow your #business #affiliatemarketing Check my #website #makemoney #earnmoney #affiliate #referral #cashback #crypto #shopping #travel #business #bitcoin #dogecoin https://t.co/vBHLD11zwQ
# 27451   #POND / #USDT acheived all take profit targets.\n\n#Congratulations.\n\nToday Accuracy So Far=100.0%, Qty =6 Signals\n\nYesterday Accuracy=78.95%, Qty =19 Signals\n\nMake money via our #trading and #referral plans (link in profile).\n\n#cryptocurrencies #Bitcoin #Binance #Alt...
#
#        lang            source  public_metrics.like_count  \
# 124960   en  ContentStudio.io                          1
# 181834   en   Twitter Web App                          0
# 121151   en  ContentStudio.io                          0
# 90140    en  ContentStudio.io                          1
# 27451    en     cryptoscalper                          0
#
#         public_metrics.quote_count  ...  entities.cashtags  author.username  \
# 124960                           0  ...                NaN  bmurphypointman
# 181834                           0  ...                NaN     ErnestWeudji
# 121151                           0  ...                NaN  bmurphypointman
# 90140                            0  ...                NaN  bmurphypointman
# 27451                            0  ...                NaN   scalperSignals
#
#        author.public_metrics.followers_count  \
# 124960                                 78399
# 181834                                    21
# 121151                                 78402
# 90140                                  78400
# 27451                                   1535
#
#        author.public_metrics.following_count  \
# 124960                                 18419
# 181834                                   426
# 121151                                 18419
# 90140                                  18419
# 27451                                     54
#
#        author.public_metrics.listed_count  geo.country  geo.country_code  \
# 124960                                546          NaN               NaN
# 181834                                  1          NaN               NaN
# 121151                                546          NaN               NaN
# 90140                                 546          NaN               NaN
# 27451                                  23          NaN               NaN
#
#                                                                                                                                                                                                                                                                                          text_l  \
# 124960                                                                               #freelance #freelancer #businessgrowth #grow #build #affiliatemarketing check my website for #affiliate #referral #cashback #crypto #shopping #travel #business #dogecoin #bitcoin https://t.co/vbhld11zwq
# 181834                                                                                @airdropinspect \n\n@airdropinspect\n#bitcoin\nchannel: https://t.co/lyic063wan\n\nbuild bots with the referral system\npromote airdrop/bounty/giveaway/referral link\n\ncontact: https://t.co/a49fmbzsfa
# 121151                         #onlinemarketing #networkingpays #online #marketing #networking #incomeforlife #payout #affiliatemarketing check my #website #makemoney #earnmoney #affiliate #referral #cashback #crypto #shopping #travel #business #bitcoin #dogecoin https://t.co/vbhld11zwq
# 90140                                #smart #seamless #freelancer #tools to #build, #manage, and #grow your #business #affiliatemarketing check my #website #makemoney #earnmoney #affiliate #referral #cashback #crypto #shopping #travel #business #bitcoin #dogecoin https://t.co/vbhld11zwq
# 27451   #pond / #usdt acheived all take profit targets.\n\n#congratulations.\n\ntoday accuracy so far=100.0%, qty =6 signals\n\nyesterday accuracy=78.95%, qty =19 signals\n\nmake money via our #trading and #referral plans (link in profile).\n\n#cryptocurrencies #bitcoin #binance #alt...
#
#        delete_project delete_airdrop
# 124960              0              0
# 181834              0              1
# 121151              0              0
# 90140               0              0
# 27451               0              0
#
# [5 rows x 23 columns]

# %% [markdown]
# Usually tweets that contain the word refferal are also spam, so lets include this as a term to delete tweets

# %%
data['delete_referral'] = np.where(data['text_l'].str.contains(r'referral'), 1, 0)
print('Proportion of tweets with the word referral:  ',data['delete_referral'].mean())
# Out:
# Proportion of tweets with the word referral:   0.0429910591503504

# %% [markdown]
# Now lets see what are some examples of tweets to delete and to keep

# %% [markdown]
# Another common word is marketing. So lets do the same process as above.

# %%
data['delete_marketing'] = np.where(data['text_l'].str.contains(r'marketing'), 1, 0)
print('Proportion of tweets with the word marketing:  ',data['delete_marketing'].mean())
# Out:
# Proportion of tweets with the word marketing:   0.06402256800131524

# %%
# Example of Tweets to remove
data[(data['delete_airdrop'] == 1) | (data['delete_referral'] == 1) | (data['delete_project'] == 1) | (data['delete_marketing'] == 1)].sample(5)
# Out:
#         Unnamed: 0                   id      conversation_id  \
# 49380         7419  1421210904750919684  1421210904750919684
# 118704      670606  1416753888569401345  1416709761777618946
# 69461       513532  1417889043786833921  1417889043786833921
# 67122      1182553  1424344228402970625  1424344228402970625
# 81556       672180  1438811977099341830  1438440496028868608
#
#                   author_id                created_at  \
# 49380   1389184389406470150  2021-07-30T20:47:39.000Z
# 118704  1297815908052738048  2021-07-18T13:37:03.000Z
# 69461   1386566605983739904  2021-07-21T16:47:45.000Z
# 67122   1293420361762009088  2021-08-08T12:18:21.000Z
# 81556   1417132958570356736  2021-09-17T10:28:01.000Z
#
#                                                                                                                                                                                                                                                                                            text  \
# 49380                                                                                                                                                                                                          Airdrop #telegram #btc @BabyDogeArt #bsc #follow\n👇👇👇\n\nhttps://t.co/03W5O1UlF7
# 118704                    @airdropinspect Thanks for giving us such a great opportunity. I am supporting it. always success for the development team to the moon Nice project.\n@alif6244 \n@vkatikk\n@WhiteAp79686089\n#Airdrop #Airdrops #Airdropinspector #AntEx #ANT #VNDT #Crypto #Bitcoin
# 69461                                                                                                             Awesome project\n\n@QuantumLeapers @PhongLee86 @RiskAc13 \n\n#Airdrop #Airdrops #Airdropinspector #Larix #LARIX #Solana #SPL #Sollet #Crypto #Bitcoin https://t.co/08z1HXKEXj
# 67122                                    #makemoneyonline #affiliatemarketing #networkmarketing #digitalmarketing #makemoney #socialmedia  #affiliatemarketing #gift #shopping #gifts #onlineshopping #dogecoin #bitcoin free shipping on purchases over $25 at #Amazon https://t.co/E0egX01ArP
# 81556   @AirdropStario I really like this airdrop, it's like a good project and in the future it will be a big project and fly high to the moon, congratulations \n@SatifFahreza  \n@iv_secret  \n@Muldans98  \n\n#cryptocurrency  #Airdrop  #BSC  #Bitcoin  #ETH  #Amplify  #AMPT  #Airdrop...
#
#        lang               source  public_metrics.like_count  \
# 49380    en  Twitter for Android                          0
# 118704   en  Twitter for Android                          0
# 69461    en      Twitter Web App                          0
# 67122    en     ContentStudio.io                          0
# 81556    en  Twitter for Android                          0
#
#         public_metrics.quote_count  ...  \
# 49380                            0  ...
# 118704                           0  ...
# 69461                            0  ...
# 67122                            0  ...
# 81556                            0  ...
#
#         author.public_metrics.followers_count  \
# 49380                                      14
# 118704                                     45
# 69461                                     132
# 67122                                     475
# 81556                                      83
#
#         author.public_metrics.following_count  \
# 49380                                     220
# 118704                                   1657
# 69461                                     910
# 67122                                     333
# 81556                                    1260
#
#        author.public_metrics.listed_count geo.country geo.country_code  \
# 49380                                   1         NaN              NaN
# 118704                                  5         NaN              NaN
# 69461                                   1         NaN              NaN
# 67122                                   7         NaN              NaN
# 81556                                   1         NaN              NaN
#
#                                                                                                                                                                                                                                                                                          text_l  \
# 49380                                                                                                                                                                                                          airdrop #telegram #btc @babydogeart #bsc #follow\n👇👇👇\n\nhttps://t.co/03w5o1ulf7
# 118704                    @airdropinspect thanks for giving us such a great opportunity. i am supporting it. always success for the development team to the moon nice project.\n@alif6244 \n@vkatikk\n@whiteap79686089\n#airdrop #airdrops #airdropinspector #antex #ant #vndt #crypto #bitcoin
# 69461                                                                                                             awesome project\n\n@quantumleapers @phonglee86 @riskac13 \n\n#airdrop #airdrops #airdropinspector #larix #larix #solana #spl #sollet #crypto #bitcoin https://t.co/08z1hxkexj
# 67122                                    #makemoneyonline #affiliatemarketing #networkmarketing #digitalmarketing #makemoney #socialmedia  #affiliatemarketing #gift #shopping #gifts #onlineshopping #dogecoin #bitcoin free shipping on purchases over $25 at #amazon https://t.co/e0egx01arp
# 81556   @airdropstario i really like this airdrop, it's like a good project and in the future it will be a big project and fly high to the moon, congratulations \n@satiffahreza  \n@iv_secret  \n@muldans98  \n\n#cryptocurrency  #airdrop  #bsc  #bitcoin  #eth  #amplify  #ampt  #airdrop...
#
#         delete_project  delete_airdrop delete_referral delete_marketing
# 49380                0               1               0                0
# 118704               1               1               0                0
# 69461                1               1               0                0
# 67122                0               0               0                1
# 81556                1               1               0                0
#
# [5 rows x 25 columns]

# %%
# Examples of tweets after removing
data[(data['delete_airdrop'] == 0) & (data['delete_referral'] == 0) & (data['delete_project'] == 0) | (data['delete_marketing'] == 0)].sample(5)
# Out:
#         Unnamed: 0                   id      conversation_id  \
# 83577      1160072  1424529982974578692  1424529982974578692
# 143306       86789  1442885284174123008  1442885284174123008
# 77918       921073  1437048689411903496  1435817095988609024
# 36382       181212  1431067980754927619  1431067980754927619
# 127910      220784  1419875233884819456  1419875233884819456
#
#                   author_id                created_at  \
# 83577             261960635  2021-08-09T00:36:29.000Z
# 143306  1357886427770535938  2021-09-28T16:13:53.000Z
# 77918   1428326174556577800  2021-09-12T13:41:21.000Z
# 36382   1200994323141054466  2021-08-27T01:36:09.000Z
# 127910  1419201618357100544  2021-07-27T04:20:10.000Z
#
#                                                                                                                                                                                                                                                                                            text  \
# 83577                                                                                                                                                               Bitcoin can't be viewed as an untraceable 'crime coin' anymore #Bitcoin via https://t.co/0NnSfBI7JQ https://t.co/3Is8FmnhuW
# 143306  It is a really LEGIT project. This is an excellent iniative with super technical team. guys let's go support this project,next big project in crypto World🔥🔥\n\n@Poll07647395\n@Eman27791242\n@Bhupindrasahu5\n\n#Airdrop #SINGIN #Bitcoin #AirdropDet #NFT #BSC #Crypto #Blockchain...
# 77918   @frxresearch @DerivedFinance is a decentralised multi chain assets protocols that features farming #staking/minting, fees and governance.\n#derived aims to propel the usage of synthetic assets in #polkadot.\ncheck out @DerivedFinance \n#bitcoin #cryptocurrency  #DEX $DVD http...
# 36382   POCO is a good project &amp; have a strong team. I think in the near future I will see an unprecedented growth of this project. Let's build a good and strong community.\n\n@fiqrinurhafizh\n@gepsif\n@rExile_0\n \n#cryptocurrency #Bitcoin   #Airdrop #nftgames #PocoLand https://...
# 127910                                                                                                          All coin follow #BTC everyday was dump pump dump pump, all people can predicted when buying or selling. If any take HODL, long time to be rich. #xrp #dogecoin #ETHEREUM #TFUEL
#
#        lang               source  public_metrics.like_count  \
# 83577    en            TwinyBots                          0
# 143306   en  Twitter for Android                          0
# 77918    en  Twitter for Android                          0
# 36382    en  Twitter for Android                          0
# 127910   en  Twitter for Android                          0
#
#         public_metrics.quote_count  ...  \
# 83577                            0  ...
# 143306                           0  ...
# 77918                            0  ...
# 36382                            0  ...
# 127910                           0  ...
#
#         author.public_metrics.followers_count  \
# 83577                                     575
# 143306                                     14
# 77918                                      84
# 36382                                       5
# 127910                                     14
#
#         author.public_metrics.following_count  \
# 83577                                       0
# 143306                                    260
# 77918                                     187
# 36382                                     266
# 127910                                    125
#
#        author.public_metrics.listed_count geo.country geo.country_code  \
# 83577                                   8         NaN              NaN
# 143306                                  9         NaN              NaN
# 77918                                   7         NaN              NaN
# 36382                                   0         NaN              NaN
# 127910                                  3         NaN              NaN
#
#                                                                                                                                                                                                                                                                                          text_l  \
# 83577                                                                                                                                                               bitcoin can't be viewed as an untraceable 'crime coin' anymore #bitcoin via https://t.co/0nnsfbi7jq https://t.co/3is8fmnhuw
# 143306  it is a really legit project. this is an excellent iniative with super technical team. guys let's go support this project,next big project in crypto world🔥🔥\n\n@poll07647395\n@eman27791242\n@bhupindrasahu5\n\n#airdrop #singin #bitcoin #airdropdet #nft #bsc #crypto #blockchain...
# 77918   @frxresearch @derivedfinance is a decentralised multi chain assets protocols that features farming #staking/minting, fees and governance.\n#derived aims to propel the usage of synthetic assets in #polkadot.\ncheck out @derivedfinance \n#bitcoin #cryptocurrency  #dex $dvd http...
# 36382   poco is a good project &amp; have a strong team. i think in the near future i will see an unprecedented growth of this project. let's build a good and strong community.\n\n@fiqrinurhafizh\n@gepsif\n@rexile_0\n \n#cryptocurrency #bitcoin   #airdrop #nftgames #pocoland https://...
# 127910                                                                                                          all coin follow #btc everyday was dump pump dump pump, all people can predicted when buying or selling. if any take hodl, long time to be rich. #xrp #dogecoin #ethereum #tfuel
#
#         delete_project  delete_airdrop delete_referral delete_marketing
# 83577                0               0               0                0
# 143306               1               1               0                0
# 77918                0               0               0                0
# 36382                1               1               0                0
# 127910               0               0               0                0
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Searching for spam accounts
#
# Another common way to filter tweets is by taking into account the user variables, ofter new accounts are created to being spam for this reason

# %%
data[data['author.public_metrics.followers_count'] < 50].sample(5)
# Out:
#         Unnamed: 0                   id      conversation_id  \
# 54686       742665  1438291282221092865  1438291282221092865
# 148755     1425276  1446738430717685763  1446738430717685763
# 97459      1481501  1422211150691799044  1421926394238439425
# 59141       159287  1420318395573014534  1420318395573014534
# 99348      1382359  1447061289717620739  1447061233723711488
#
#                   author_id                created_at  \
# 54686   1403583480827498497  2021-09-15T23:58:58.000Z
# 148755  1303152744807583744  2021-10-09T07:24:55.000Z
# 97459   1414603696999043082  2021-08-02T15:02:16.000Z
# 59141   1372834025715343360  2021-07-28T09:41:08.000Z
# 99348   1446670186677997575  2021-10-10T04:47:51.000Z
#
#                                                                                                                                                                                                                                                                                            text  \
# 54686                                                               Good projects and i Will be supported on this projects\n\n@nraykov66\n \n@coin_running\n \n@rasita\n\n#Airdrop #Airdrops #Airdropinspector #BinanceSmartChain #BSC #HOS #FastHorse #Crypto #Bitcoin https://t.co/DnIxRiB3iT
# 148755                                                                                                                                    @Lonesai6 @Nuopie1 @ChueCrypto great project #BTC #Solana #Bsc #ETH #Polygon #Polkadot #HecoChain #Launchpad #investing #DeFi https://t.co/lVHbYyb3mB
# 97459   @project_euro Potential project and I know this Project will success\nI believe this is a faithful project.\n\n@AtiKHaS45145424\n@Joysaha07526272\n@Aiden5_31\n\n#beuropro #bitcoin #btc #cryptocurrency #cryptonews \n#finance #forex #invest #investing #investment \n#investor #t...
# 59141                                            I believe this is a faithful project.The projector has a lot of attractions so hopefully the project will be better in the future and will be the best.\n@asepyusuf\n@Agunghasanu271 \n@CRDTpay \n\n#bsc #BTC #Airdrop https://t.co/b3BEadyBhM
# 99348   @Co2Heal https://t.co/o92SE3U2J3\n\nI'm farming my bitcoin on this app, feels good to invest in #shibainu with this application, do like me i do not regret since the first day.\n\n#shib #NIO #shibainu #MOASS #GME  #AMCSTRONG #AMCSqueeze #AMCtothemoon #Bitcoin #etherium https:...
#
#        lang               source  public_metrics.like_count  \
# 54686    en      Twitter Web App                          0
# 148755   en      Twitter Web App                          0
# 97459    en  Twitter for Android                          0
# 59141    en  Twitter for Android                          0
# 99348    en      Twitter Web App                          0
#
#         public_metrics.quote_count  ...  \
# 54686                            0  ...
# 148755                           0  ...
# 97459                            0  ...
# 59141                            0  ...
# 99348                            0  ...
#
#         author.public_metrics.followers_count  \
# 54686                                      12
# 148755                                     23
# 97459                                      20
# 59141                                      49
# 99348                                       0
#
#         author.public_metrics.following_count  \
# 54686                                     303
# 148755                                   1155
# 97459                                     741
# 59141                                    2459
# 99348                                       5
#
#        author.public_metrics.listed_count geo.country geo.country_code  \
# 54686                                   0         NaN              NaN
# 148755                                  4         NaN              NaN
# 97459                                   2         NaN              NaN
# 59141                                   8         NaN              NaN
# 99348                                   0         NaN              NaN
#
#                                                                                                                                                                                                                                                                                          text_l  \
# 54686                                                               good projects and i will be supported on this projects\n\n@nraykov66\n \n@coin_running\n \n@rasita\n\n#airdrop #airdrops #airdropinspector #binancesmartchain #bsc #hos #fasthorse #crypto #bitcoin https://t.co/dnixrib3it
# 148755                                                                                                                                    @lonesai6 @nuopie1 @chuecrypto great project #btc #solana #bsc #eth #polygon #polkadot #hecochain #launchpad #investing #defi https://t.co/lvhbyyb3mb
# 97459   @project_euro potential project and i know this project will success\ni believe this is a faithful project.\n\n@atikhas45145424\n@joysaha07526272\n@aiden5_31\n\n#beuropro #bitcoin #btc #cryptocurrency #cryptonews \n#finance #forex #invest #investing #investment \n#investor #t...
# 59141                                            i believe this is a faithful project.the projector has a lot of attractions so hopefully the project will be better in the future and will be the best.\n@asepyusuf\n@agunghasanu271 \n@crdtpay \n\n#bsc #btc #airdrop https://t.co/b3beadybhm
# 99348   @co2heal https://t.co/o92se3u2j3\n\ni'm farming my bitcoin on this app, feels good to invest in #shibainu with this application, do like me i do not regret since the first day.\n\n#shib #nio #shibainu #moass #gme  #amcstrong #amcsqueeze #amctothemoon #bitcoin #etherium https:...
#
#         delete_project  delete_airdrop delete_referral delete_marketing
# 54686                1               1               0                0
# 148755               1               0               0                0
# 97459                0               0               0                0
# 59141                1               1               0                0
# 99348                0               0               0                0
#
# [5 rows x 25 columns]

# %%
data['delete_followers'] = np.where(data['author.public_metrics.followers_count'] < 30, 1, 0)
print(data['delete_followers'].mean())
# Out:
# 0.17034477354405816

# %%
### Count and delete the spam tweets
print('Project:', data['delete_project'].sum(), data['delete_project'].mean())
print('Airdrop:', data['delete_airdrop'].sum(), data['delete_airdrop'].mean())
print('Referal:', data['delete_referral'].sum(), data['delete_referral'].mean())
print('Followers:', data['delete_followers'].sum(), data['delete_followers'].mean())


ini_number = data.shape[0]
print('Initial number of tweets:', ini_number)

data = data[(data['delete_airdrop'] == 0) & (data['delete_referral'] == 0) & (data['delete_project'] == 0) & (data['delete_marketing'] == 0) & (data['delete_followers'] == 0)].copy()
fin_number = data.shape[0]

print('Final number of tweets:', fin_number)
print('Total tweets removed:', ini_number - fin_number,  fin_number/ini_number)
# Out:
# Project: 95228 0.14631710438776152
# Airdrop: 127774 0.1963237881299811
# Referal: 27980 0.0429910591503504
# Followers: 110866 0.17034477354405816
# Initial number of tweets: 650833
# Final number of tweets: 384647
# Total tweets removed: 266186 0.5910072169051047

# %%
# Summary of the code to delete tweets
data['text_l'] = data['text'].str.lower()

data['delete_project'] = np.where(data['text_l'].str.contains(r'^(?=.*\b(?:best|strong|awesome|amazing|great|big|excellent|good|nice)\b).*project'), 1, 0)
data['delete_airdrop'] = np.where(data['text_l'].str.contains(r'airdrop'), 1, 0)
data['delete_referral'] = np.where(data['text_l'].str.contains(r'referral'), 1, 0)
data['delete_marketing'] = np.where(data['text_l'].str.contains(r'marketing'), 1, 0)
data['delete_followers'] = np.where(data['author.public_metrics.followers_count'] < 30, 1, 0)

data = data[(data['delete_airdrop'] == 0) & (data['delete_referral'] == 0) & (data['delete_project'] == 0) & (data['delete_marketing'] == 0) & (data['delete_followers'] == 0)].copy()
print(data.shape)
# Out:
# (384647, 26)
